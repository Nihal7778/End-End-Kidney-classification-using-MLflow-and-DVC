# %%
#config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
#ensure annotations
from ensure import ensure_annotations

@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x*y

# %%
get_product(2, 3)
# Out:
# 6

# %% [markdown]
# Downloading data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1vlR39c46AZAOded2SlWVNYWA1iysWjTb/view?usp=drive_link"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1vlR39c46AZAOded2SlWVNYWA1iysWjTb'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1vlR39c46AZAOded2SlWVNYWA1iysWjTb
# To: /Users/nihal/Downloads/End-End-Kidney-classification-using-MLflow-and-DVC/research/Chest-CT-Scan-data.zip
# 100%|██████████| 11.6M/11.6M [00:00<00:00, 21.1MB/s]
# 'Chest-CT-Scan-data.zip'
